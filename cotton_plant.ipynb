# %% [markdown]
# <a href="https://colab.research.google.com/github/Thahani114/.Calc/blob/main/cotton_plant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 565.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 102.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 98.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 107.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from skimage.transform import resize
from  glob import glob
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential,layers,applications
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
aphids = glob('/content/drive/MyDrive/Cotton plant/Cotton Plant Disease Dataset/Cotton plant/Cotton plant/Aphids/*.jpg')
armyworm = glob('/content/drive/MyDrive/Cotton plant/Cotton Plant Disease Dataset/Cotton plant/Cotton plant/Army worm/*.jpg')
bacterialblight = glob('/content/drive/MyDrive/Cotton plant/Cotton Plant Disease Dataset/Cotton plant/Cotton plant/Bacterial Blight/*.jpg')
healthy = glob('/content/drive/MyDrive/Cotton plant/Cotton Plant Disease Dataset/Cotton plant/Cotton plant/Healthy/*.jpg')
powdery = glob('/content/drive/MyDrive/Cotton plant/Cotton Plant Disease Dataset/Cotton plant/Cotton plant/Powdery Mildew/*.jpg')
targetspot = glob('/content/drive/MyDrive/Cotton plant/Cotton Plant Disease Dataset/Cotton plant/Cotton plant/Target spot/*.jpg')

# %%
images=[]
labels=[]

for i in targetspot:
    img=plt.imread(i)
    images.append(img)
    labels.append(0)

for i in powdery:
    img=plt.imread(i)
    images.append(img)
    labels.append(1)

for i in healthy:
    img=plt.imread(i)
    images.append(img)
    labels.append(2)

for i in bacterialblight:
    img=plt.imread(i)
    images.append(img)
    labels.append(3)

for i in armyworm:
    img=plt.imread(i)
    images.append(img)
    labels.append(4)

for i in aphids:
    img=plt.imread(i)
    images.append(img)
    labels.append(5)

# %%
classes={0:'targetspot', 1:'powdery', 2:'healthy', 3:'bacterialblight', 4:'armyworm', 5:'aphids'}

# %%
from sklearn.utils import shuffle
images,labels=shuffle(images,labels,random_state=100)

# %%
print(len(targetspot))
print(len(aphids))
print(len(powdery))
print(len(armyworm))
print(len(healthy))
print(len(bacterialblight))
# Out:
# 390
# 400
# 400
# 400
# 390
# 400

# %%
plt.figure(figsize=(12,6))
for i in range (12):
    plt.subplot(3,4,i+1)
    plt.imshow(images[i])
    plt.title(classes[labels[i]])

plt.tight_layout()

# %%
for i in range (10):
    print(images[i].shape)
# Out:
# (480, 720, 3)
# (233, 384, 3)
# (420, 840, 3)
# (300, 768, 3)
# (300, 768, 3)
# (691, 691, 3)
# (168, 300, 3)
# (697, 597, 3)
# (640, 800, 3)
# (994, 1500, 3)

# %%
from skimage.transform import resize

X=[]
for i in images:
    X.append(resize(i,(224,224,3)))

X=np.array(X)

y=np.array(labels)

# %%
plt.figure(figsize=(12,6))
for i in range (12):
    plt.subplot(3,4,i+1)
    plt.imshow(X[i])
    plt.title(classes[y[i]])

plt.tight_layout()

# %%
for i in range (10):
    print(images[i].shape)
# Out:
# (480, 720, 3)
# (233, 384, 3)
# (420, 840, 3)
# (300, 768, 3)
# (300, 768, 3)
# (691, 691, 3)
# (168, 300, 3)
# (697, 597, 3)
# (640, 800, 3)
# (994, 1500, 3)

# %%
# !pip install tensorflow-hub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.2 MB/s eta 0:00:00
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=100)

# %%
print(X.shape)
print(y.shape)
# Out:
# (2380, 224, 224, 3)
# (2380,)

# %%
# !pip install tensorflow-hub

# %%
pip install --upgrade tensorflow tensorflow-hub

# %%
# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-hub

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model

num_of_classes = 6

# Define the input tensor
input_layer = tf.keras.Input(shape=(224, 224, 3))

# Load MobileNetV2 model pre-trained on ImageNet (exclude the top classification layer)
mobilenet_v2_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the MobileNetV2 model
mobilenet_v2_model.trainable = False

# Pass the input through the pre-trained model
x = mobilenet_v2_model(input_layer)

# Flatten the output of the MobileNetV2 model
x = tf.keras.layers.GlobalAveragePooling2D()(x)

# Add custom layers
x = Dense(64, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(14, activation='relu')(x)

# Define the output layer
x = Dense(num_of_classes, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_layer, outputs=x)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.fit(X_train,y_train, epochs = 10, validation_split = 0.05)
# Out:
# Epoch 1/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.3730 - loss: 1.5561 - val_accuracy: 0.8438 - val_loss: 0.6538
# Epoch 2/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - accuracy: 0.8117 - loss: 0.6039 - val_accuracy: 0.9479 - val_loss: 0.2826
# Epoch 3/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.9083 - loss: 0.3187 - val_accuracy: 0.9479 - val_loss: 0.2029
# Epoch 4/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - accuracy: 0.9369 - loss: 0.2103 - val_accuracy: 0.9688 - val_loss: 0.1221
# Epoch 5/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - accuracy: 0.9639 - loss: 0.1366 - val_accuracy: 0.9896 - val_loss: 0.0986
# Epoch 6/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - accuracy: 0.9839 - loss: 0.0757 - val_accuracy: 0.9896 - val_loss: 0.0827
# Epoch 7/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - accuracy: 0.9870 - loss: 0.0618 - val_accuracy: 0.9896 - val_loss: 0.0881
# Epoch 8/10
# ...

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
y_pred = model.predict(X_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step

# %%
y_pred = [np.argmax(i) for i in y_pred]

# %%
y_pred
# Out:
# [np.int64(4),
#  np.int64(1),
#  np.int64(5),
#  np.int64(4),
#  np.int64(5),
#  np.int64(1),
#  np.int64(4),
#  np.int64(1),
#  np.int64(0),
#  np.int64(4),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(3),
#  np.int64(0),
#  np.int64(4),
#  np.int64(1),
#  np.int64(4),
#  np.int64(4),
#  np.int64(2),
#  np.int64(4),
#  np.int64(4),
#  np.int64(1),
#  np.int64(1),
#  np.int64(4),
#  np.int64(1),
#  np.int64(5),
#  np.int64(5),
#  np.int64(2),
#  np.int64(2),
#  np.int64(3),
#  np.int64(0),
#  np.int64(1),
#  np.int64(5),
#  np.int64(4),
#  np.int64(0),
#  np.int64(3),
#  np.int64(3),
#  np.int64(4),
#  np.int64(0),
#  np.int64(5),
#  np.int64(0),
#  np.int64(4),
#  np.int64(0),
#  np.int64(4),
#  np.int64(3),
#  np.int64(3),
#  np.int64(4),
#  np.int64(0),
#  np.int64(1),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(0),
#  np.int64(5),
#  np.int64(3),
#  np.int64(0),
#  np.int64(4),
#  np.int64(4),
#  np.int64(5),
#  np.int64(3),
#  np.int64(1),
# ...

# %%
len(y_pred)
# Out:
# 476

# %%
plt.figure(figsize=(12,6))
for i in range (12):
    plt.subplot(3,4,i+1)
    plt.imshow(X_test[i])
    plt.title(classes[y_pred[i]])

plt.tight_layout()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

print(f"Accuracy is : {accuracy_score(y_test,y_pred)}")
# Out:
# Accuracy is : 0.9411764705882353

# %%
sns.heatmap(confusion_matrix(y_test,y_pred), annot = True, fmt = 'd')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        74
#            1       0.99      0.93      0.96        82
#            2       0.96      0.99      0.97        75
#            3       1.00      0.87      0.93        78
#            4       0.98      0.92      0.95        92
#            5       0.85      0.97      0.91        75
#
#     accuracy                           0.94       476
#    macro avg       0.94      0.94      0.94       476
# weighted avg       0.95      0.94      0.94       476
